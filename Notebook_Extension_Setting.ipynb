# %% [markdown]
# ## Guide for setting of NBextensions
#
#
#  _With this code we can  get_
#
#   - 'executed in 16ms, finished 20:53:37 2022-05-15 ' at the end of every cell
#   - other useful extensions

# %%
# Step 1 - download of package
pip install jupyter_contrib_nbextensions

#You can install it only once if you try to run it gain it will throw error as it has been already installed

# %%
#Step 2 - installation of package 

# !jupyter contrib nbextension install --user

'''You can see a new tab beside running and clusters at home page of jupyter notebook'''

# %% [markdown]
# ![Screenshot%202022-05-15%2020.47.21.png](attachment:Screenshot%202022-05-15%2020.47.21.png)

# %%
#Step 3 - selection of required tools
'''Choose other extensions if you want'''

# %% [markdown]
# ![Screenshot%202022-05-15%2020.49.42.png](attachment:Screenshot%202022-05-15%2020.49.42.png)

# %% [markdown]
# '''Addition of images in jupyter notebook - Markdown ---> Edit ---> Insert Image'''
